# %%
# imports
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import pickle
import community as community_louvain  # pip install python-louvain
from collections import defaultdict

# %%
# Extract the dataframe (aggregated)
path1 = "../dataframes/df_aggregated.pk1"
with open(path1, "rb") as f:
    df = pickle.load(f)

# %% [markdown]
# # Extract Information for Gephi

# %% [markdown]
# ### Using Cosine similarity
# The goal is to measure the direct similarity between diseases based on their symptom vectors (or features),

# %%
# Get disease names
diseases = df.iloc[:, 0]

# %%
# Extract symptom matrix 
symptom_matrix = df.iloc[:, 1:].values  

# Check dimensions
print("Number of diseases:", len(diseases))
print("Number of symptoms:", symptom_matrix.shape[1])
print("Symptom matrix shape:", symptom_matrix.shape)
# Out:
# Number of diseases: 773
# Number of symptoms: 377
# Symptom matrix shape: (773, 377)

# %%
# Compute cosine similarity matrix
cosine_sim_matrix = cosine_similarity(symptom_matrix)

# %%
# Convert similarity matrix to df
cosine_df = pd.DataFrame(cosine_sim_matrix, index=diseases, columns=diseases)

# %%
cosine_df
# Out:
# diseases                   abdominal aortic aneurysm  abdominal hernia  \
# diseases
# abdominal aortic aneurysm                   1.000000          0.129099
# abdominal hernia                            0.129099          1.000000
# abscess of nose                             0.000000          0.000000
# abscess of the lung                         0.204124          0.000000
# abscess of the pharynx                      0.000000          0.000000
# ...                                              ...               ...
# white blood cell disease                    0.136083          0.105409
# whooping cough                              0.182574          0.000000
# wilson disease                              0.000000          0.000000
# yeast infection                             0.136083          0.105409
# zenker diverticulum                         0.000000          0.000000
#
# diseases                   abscess of nose  abscess of the lung  \
# diseases
# abdominal aortic aneurysm         0.000000             0.204124
# abdominal hernia                  0.000000             0.000000
# abscess of nose                   1.000000             0.176777
# abscess of the lung               0.176777             1.000000
# abscess of the pharynx            0.500000             0.176777
# ...                                    ...                  ...
# white blood cell disease          0.353553             0.166667
# whooping cough                    0.632456             0.447214
# wilson disease                    0.204124             0.288675
# yeast infection                   0.000000             0.000000
# zenker diverticulum               0.204124             0.000000
#
# diseases                   abscess of the pharynx  acanthosis nigricans  \
# diseases
# abdominal aortic aneurysm                0.000000                   0.0
# abdominal hernia                         0.000000                   0.0
# abscess of nose                          0.500000                   0.0
# abscess of the lung                      0.176777                   0.0
# abscess of the pharynx                   1.000000                   0.0
# ...                                           ...                   ...
# white blood cell disease                 0.235702                   0.0
# whooping cough                           0.474342                   0.0
# wilson disease                           0.204124                   0.0
# yeast infection                          0.000000                   0.0
# zenker diverticulum                      0.408248                   0.0
#
# diseases                   acariasis  achalasia      acne  actinic keratosis  \
# diseases
# abdominal aortic aneurysm   0.000000   0.000000  0.000000           0.000000
# abdominal hernia            0.000000   0.000000  0.000000           0.000000
# abscess of nose             0.000000   0.158114  0.000000           0.000000
# abscess of the lung         0.000000   0.223607  0.000000           0.000000
# abscess of the pharynx      0.000000   0.474342  0.000000           0.000000
# ...                              ...        ...       ...                ...
# white blood cell disease    0.000000   0.149071  0.000000           0.000000
# whooping cough              0.000000   0.200000  0.000000           0.000000
# wilson disease              0.000000   0.258199  0.000000           0.000000
# yeast infection             0.166667   0.000000  0.111111           0.100504
# zenker diverticulum         0.000000   0.258199  0.000000           0.000000
#
# diseases                   ...  von willebrand disease  vulvar cancer  \
# diseases                   ...
# abdominal aortic aneurysm  ...                     0.0       0.235702
# abdominal hernia           ...                     0.0       0.000000
# abscess of nose            ...                     0.0       0.000000
# abscess of the lung        ...                     0.0       0.000000
# abscess of the pharynx     ...                     0.0       0.000000
# ...                        ...                     ...            ...
# white blood cell disease   ...                     0.0       0.000000
# whooping cough             ...                     0.0       0.000000
# wilson disease             ...                     0.0       0.333333
# yeast infection            ...                     0.0       0.000000
# zenker diverticulum        ...                     0.0       0.000000
#
# diseases                   vulvar disorder  vulvodynia  \
# diseases
# abdominal aortic aneurysm         0.000000    0.353553
# abdominal hernia                  0.000000    0.182574
# abscess of nose                   0.000000    0.000000
# abscess of the lung               0.000000    0.000000
# abscess of the pharynx            0.000000    0.000000
# ...                                    ...         ...
# white blood cell disease          0.000000    0.192450
# whooping cough                    0.000000    0.000000
# wilson disease                    0.000000    0.000000
# yeast infection                   0.408248    0.384900
# zenker diverticulum               0.000000    0.000000
#
# diseases                   wernicke korsakoff syndrome  \
# diseases
# abdominal aortic aneurysm                     0.000000
# abdominal hernia                              0.000000
# abscess of nose                               0.000000
# abscess of the lung                           0.288675
# abscess of the pharynx                        0.000000
# ...                                                ...
# white blood cell disease                      0.000000
# whooping cough                                0.000000
# wilson disease                                0.000000
# yeast infection                               0.000000
# zenker diverticulum                           0.000000
#
# diseases                   white blood cell disease  whooping cough  \
# diseases
# abdominal aortic aneurysm                  0.136083        0.182574
# abdominal hernia                           0.105409        0.000000
# abscess of nose                            0.353553        0.632456
# abscess of the lung                        0.166667        0.447214
# abscess of the pharynx                     0.235702        0.474342
# ...                                             ...             ...
# white blood cell disease                   1.000000        0.298142
# whooping cough                             0.298142        1.000000
# wilson disease                             0.192450        0.258199
# yeast infection                            0.111111        0.000000
# zenker diverticulum                        0.000000        0.258199
#
# diseases                   wilson disease  yeast infection  \
# diseases
# abdominal aortic aneurysm        0.000000         0.136083
# abdominal hernia                 0.000000         0.105409
# abscess of nose                  0.204124         0.000000
# abscess of the lung              0.288675         0.000000
# abscess of the pharynx           0.204124         0.000000
# ...                                   ...              ...
# white blood cell disease         0.192450         0.111111
# whooping cough                   0.258199         0.000000
# wilson disease                   1.000000         0.000000
# yeast infection                  0.000000         1.000000
# zenker diverticulum              0.000000         0.000000
#
# diseases                   zenker diverticulum
# diseases
# abdominal aortic aneurysm             0.000000
# abdominal hernia                      0.000000
# abscess of nose                       0.204124
# abscess of the lung                   0.000000
# abscess of the pharynx                0.408248
# ...                                        ...
# white blood cell disease              0.000000
# whooping cough                        0.258199
# wilson disease                        0.000000
# yeast infection                       0.000000
# zenker diverticulum                   1.000000
#
# [773 rows x 773 columns]

# %%
# Set diagonal values to 0 (self-similarity)
np.fill_diagonal(cosine_sim_matrix, 0)

# Find max similarity value (off-diagonal)
max_sim = np.max(cosine_sim_matrix)

# Find disease pairs with max similarity
max_pairs = np.argwhere(cosine_sim_matrix == max_sim)

# %%
# Extract upper triangle (to avoid duplicate pairs)
upper_triangle_indices = np.triu_indices_from(cosine_sim_matrix, k=1)

# Get disease pairs and similarity scores
similarity_scores = cosine_sim_matrix[upper_triangle_indices]
disease_pairs = [(diseases[i], diseases[j]) for i, j in zip(*upper_triangle_indices)]

# df disease pairs and similarities
similarity_df = pd.DataFrame(disease_pairs, columns=["Disease 1", "Disease 2"])
similarity_df["Cosine Similarity"] = similarity_scores

# %%
similarity_df
# Out:
#                         Disease 1               Disease 2  Cosine Similarity
# 0       abdominal aortic aneurysm        abdominal hernia           0.129099
# 1       abdominal aortic aneurysm         abscess of nose           0.000000
# 2       abdominal aortic aneurysm     abscess of the lung           0.204124
# 3       abdominal aortic aneurysm  abscess of the pharynx           0.000000
# 4       abdominal aortic aneurysm    acanthosis nigricans           0.000000
# ...                           ...                     ...                ...
# 298373             whooping cough         yeast infection           0.000000
# 298374             whooping cough     zenker diverticulum           0.258199
# 298375             wilson disease         yeast infection           0.000000
# 298376             wilson disease     zenker diverticulum           0.000000
# 298377            yeast infection     zenker diverticulum           0.000000
#
# [298378 rows x 3 columns]

# %%
# Create a disease list from the top 50 pairs (unique diseases)
diseases_list = np.unique(disease_pairs)

# %%
# Create a zero matrix for the similarity values between diseases
similarity_matrix = np.zeros((len(diseases_list), len(diseases_list)))
similarity_values = similarity_df["Cosine Similarity"].values

# %% [markdown]
# ## Translate Data for Gephi Import
# Utilizing community analysis to create unique .csv files to import for our Gephi visual

# %%
disease_pairs = similarity_df[['Disease 1', 'Disease 2']].values
similarity_values = similarity_df['Cosine Similarity'].values

# %%
# Create edge list for Gephi (Source, Target, Weight)
edge_list = []
for (disease_1, disease_2), similarity in zip(disease_pairs, similarity_values):
    if similarity > 0:  # Only include edges with similarity > 0
        edge_list.append([disease_1, disease_2, similarity])

edge_df = pd.DataFrame(edge_list, columns=["Source", "Target", "Weight"])
# edge_df.to_csv("disease_similarity_edge_list.csv", index=False)

# %%
# Create a graph from the edge list
G = nx.Graph()
for (disease_1, disease_2), similarity in zip(disease_pairs, similarity_values):
    if similarity > 0:
        G.add_edge(disease_1, disease_2, weight=similarity)

# Apply Louvain
partition = community_louvain.best_partition(G, weight='weight')

# Create a node list with correct ID and Label format
# Create a mapping of diseases to unique indices
disease_to_index = {disease: idx for idx, disease in enumerate(G.nodes())}

# Create a node list with unique ID, disease name, and community ID
node_list = []
for disease, community_id in partition.items():
    node_list.append([disease_to_index[disease], disease, community_id])  # Use unique index as ID

# Convert to DataFrame and save node list
node_df = pd.DataFrame(node_list, columns=["Id", "Label", "Community"])
node_df.to_csv("disease_nodes_with_communities.csv", index=False)

# %%
# Filter the rows where the Community column has a value of 6
community_6_nodes = node_df[node_df["Community"] == 6]

# Check if any rows exist with community ID 6
if community_6_nodes.empty:
    print("There are no nodes with community ID 6.")
else:
    print(f"Nodes with community ID 6:\n{community_6_nodes}")
# Out:
# Nodes with community ID 6:
#       Id                                    Label  Community
# 73    73                            drug reaction          6
# 80    80  envenomation from spider or animal bite          6
# 103  103                             gynecomastia          6
# 180  180                            osteomyelitis          6
# 190  190                        parasitic disease          6
# ..   ...                                      ...        ...
# 619  619                         oral leukoplakia          6
# 622  622                            tooth abscess          6
# 736  736                             fibroadenoma          6
# 742  742                            breast cancer          6
# 771  771               fibrocystic breast disease          6
#
# [91 rows x 3 columns]

# %%
# Get unique community IDs
unique_communities = set(partition.values())

# Get the number of unique communities
num_communities = len(unique_communities)

print(f"Number of communities: {num_communities}")
# Out:
# Number of communities: 7

# %%
unique_communities = set(partition.values())
print(f"Unique community IDs: {unique_communities}")
# Out:
# Unique community IDs: {0, 1, 2, 3, 4, 5, 6}

# %%
node_df
# Out:
#       Id                             Label  Community
# 0      0         abdominal aortic aneurysm          2
# 1      1                  abdominal hernia          2
# 2      2               abscess of the lung          1
# 3      3               acute bronchiolitis          1
# 4      4                  acute bronchitis          1
# ..   ...                               ...        ...
# 768  768  trigger finger (finger disorder)          4
# 769  769          open wound of the finger          4
# 770  770            open wound of the hand          4
# 771  771        fibrocystic breast disease          0
# 772  772          open wound due to trauma          4
#
# [773 rows x 3 columns]

# %%
num_communities = len(set(partition.values()))
print(f"Number of Communities: {num_communities}")
# Out:
# Number of Communities: 6

# %%
# Create a dictionary to group diseases by community
community_groups = defaultdict(list)
for disease, community_id in partition.items():
    community_groups[community_id].append(disease)

# Open a file in write mode to save the communities and their diseases
with open("diseases_per_community.txt", "w") as f:
    for community_id, diseases in community_groups.items():
        f.write(f"Community {community_id}:\n")
        for disease in diseases:
            f.write(f"  - {disease}\n")
        f.write("\n")  # Add an empty line between communities for readability

# Optional: Print the output to the notebook as well
with open("diseases_per_community.txt", "r") as f:
    print(f.read())
# Out:
# Community 2:
#   - abdominal aortic aneurysm
#   - abdominal hernia
#   - acute fatty liver of pregnancy (aflp)
#   - acute kidney injury
#   - acute pancreatitis
#   - adrenal adenoma
#   - alcoholic liver disease
#   - anal fissure
#   - appendicitis
#   - ascending cholangitis
#   - benign kidney cyst
#   - benign vaginal discharge (leukorrhea)
#   - bladder disorder
#   - celiac disease
#   - cervical disorder
#   - cervicitis
#   - chlamydia
#   - cholecystitis
#   - choledocholithiasis
#   - chronic constipation
#   - chronic pancreatitis
#   - cirrhosis
#   - colonic polyp
#   - colorectal cancer
#   - crohn disease
#   - cystitis
#   - diabetic ketoacidosis
#   - diverticulitis
#   - diverticulosis
#   - drug withdrawal
#   - ectopic pregnancy
#   - endometriosis
#   - epididymitis
#   - esophageal cancer
#   - fluid overload
#   - foreign body in the gastrointestinal tract
#   - gallstone
#   - gas gangrene
#   - gastritis
#   - gastroduodenal ulcer
#   - gastrointestinal hemorrhage
#   - gastroparesis
#   - gonorrhea
#   - hematoma
#   - hemorrhoids
#   - hepatitis due to a toxin
#   - hiatal hernia
#   - hirschsprung disease
#   - hydatidiform mole
#   - hydronephrosis
#   - hyperemesis gravidarum
#   - hypokalemia
#   - hyponatremia
#   - hypovolemia
#   - idiopathic absence of menstruation
#   - idiopathic excessive menstruation
#   - idiopathic infrequent menstruation
#   - idiopathic irregular menstrual cycle
#   - idiopathic nonmenstrual bleeding
#   - idiopathic painful menstruation
#   - ileus
#   - indigestion
#   - induced abortion
#   - infectious gastroenteritis
#   - inguinal hernia
#   - injury to internal organ
#   - injury to the abdomen
#   - intestinal cancer
#   - intestinal disease
#   - intestinal malabsorption
#   - intestinal obstruction
#   - intussusception
#   - irritable bowel syndrome
#   - ischemia of the bowel
#   - kidney stone
#   - liver cancer
#   - liver disease
#   - retinopathy due to high blood pressure
#   - uveitis
#   - vitreous degeneration
#   - vitreous hemorrhage
#   - rheumatic fever

# %%
# Compute Betweenness Centrality
betweenness = nx.betweenness_centrality(G, weight='weight', k=100)

df = pd.DataFrame([(disease_to_index[disease], bet) for disease, bet in betweenness.items()], 
                  columns=["Id", "Betweenness"])
df.to_csv("betweenness_values.csv", index=False)

# %%
# Load similarity data
disease_pairs = similarity_df[['Disease 1', 'Disease 2']].values
similarity_values = similarity_df['Cosine Similarity'].values

# Create a graph from the edge list
G = nx.Graph()
for (disease_1, disease_2), similarity in zip(disease_pairs, similarity_values):
    if similarity > 0:  # Only include edges with similarity > 0
        G.add_edge(disease_1, disease_2, weight=similarity)

# Apply Louvain
partition = community_louvain.best_partition(G, weight='weight')

# Create a mapping of diseases to unique indices
disease_to_index = {disease: idx for idx, disease in enumerate(G.nodes())}

# Compute degrees
degree_dict = dict(G.degree())

# Dictionary of diseases by community 
community_groups = defaultdict(list)
for disease, community_id in partition.items():
    community_groups[community_id].append(disease)

# Store top 4-5 highest-degree nodes per community
top_nodes_per_community = []

for community_id, diseases_in_community in community_groups.items():
    if len(diseases_in_community) > 1:  # Only consider meaningful communities
        # Sort diseases by degree in descending order
        sorted_diseases = sorted(diseases_in_community, key=lambda d: degree_dict.get(d, 0), reverse=True)
        # Take the top 4 or 5 (if at least 5 exist)
        top_diseases = sorted_diseases[:5]

        for disease in top_diseases:
            top_nodes_per_community.append([
                community_id,
                disease_to_index[disease], 
                disease, 
                degree_dict[disease]
            ])

# Convert to DataFrame and save
top_nodes_df = pd.DataFrame(top_nodes_per_community, columns=["Community", "Id", "Label", "Degree"])
top_nodes_df.to_csv("top_degree_nodes_per_community.csv", index=False)

# %%
# Create edge list with IDs
edge_list = []
for (disease_1, disease_2), similarity in zip(disease_pairs, similarity_values):
    if similarity > 0:
        edge_list.append([
            disease_to_index[disease_1],  # Convert Source to ID
            disease_to_index[disease_2],  # Convert Target to ID
            similarity
        ])

# Convert to DataFrame and save
edge_df = pd.DataFrame(edge_list, columns=["Source", "Target", "Weight"])
edge_df.to_csv("disease_similarity_edge_list.csv", index=False)

# %%
# Print the highest-degree nodes per community in Jupyter Notebook
for community_id, diseases_in_community in community_groups.items():
    if len(diseases_in_community) > 1:  # Only consider meaningful communities
        sorted_diseases = sorted(diseases_in_community, key=lambda d: degree_dict.get(d, 0), reverse=True)
        top_diseases = sorted_diseases[:5]  # Get top 4-5 nodes

        print(f"\nCommunity {community_id}:")
        for disease in top_diseases:
            print(f"  - {disease} (Degree: {degree_dict[disease]})")
# Out:
# Community 3:
#   - hypokalemia (Degree: 403)
#   - pain after an operation (Degree: 390)
#   - gastritis (Degree: 363)
#   - diabetic ketoacidosis (Degree: 355)
#   - esophagitis (Degree: 355)
#
# Community 1:
#   - acute kidney injury (Degree: 367)
#   - pleural effusion (Degree: 361)
#   - sarcoidosis (Degree: 341)
#   - hyperkalemia (Degree: 336)
#   - smoking or tobacco addiction (Degree: 336)
#
# Community 2:
#   - strep throat (Degree: 353)
#   - lymphadenitis (Degree: 352)
#   - sepsis (Degree: 351)
#   - acute bronchitis (Degree: 323)
#   - flu (Degree: 317)
#
# Community 4:
#   - acute stress reaction (Degree: 381)
#   - lyme disease (Degree: 357)
#   - intracerebral hemorrhage (Degree: 355)
#   - intracranial hemorrhage (Degree: 351)
#   - malignant hypertension (Degree: 346)
#
# Community 5:
#   - sickle cell crisis (Degree: 362)
#   - chronic pain disorder (Degree: 346)
#   - muscle spasm (Degree: 317)
#   - fibromyalgia (Degree: 310)
#   - injury to the trunk (Degree: 296)
#
# Community 6:
#   - drug reaction (Degree: 392)
#   - shingles (herpes zoster) (Degree: 379)
#   - parasitic disease (Degree: 331)
#   - vasculitis (Degree: 310)
#   - viral exanthem (Degree: 289)
#
# Community 0:
#   - migraine (Degree: 304)
#   - subarachnoid hemorrhage (Degree: 303)
#   - bell palsy (Degree: 268)
#   - trigeminal neuralgia (Degree: 242)
#   - pseudotumor cerebri (Degree: 234)

# %%
print(f"Total number of communities: {len(community_groups)}")
# Out:
# Total number of communities: 7

# %%
# Compute node degrees
degree_dict = dict(G.degree(weight=None))  # unweighted degree

# Create list to store scored pairs
scored_pairs = []

for idx, row in similarity_df.iterrows():
    d1 = row['Disease 1']
    d2 = row['Disease 2']
    similarity = row['Cosine Similarity']
    
    # Only consider connected pairs with similarity > 0
    if similarity > 0 and G.has_edge(d1, d2):
        deg1 = degree_dict.get(d1, 0)
        deg2 = degree_dict.get(d2, 0)
        avg_deg = (deg1 + deg2) / 2
        misdiagnosis_score = similarity * avg_deg
        
        scored_pairs.append({
            'Disease 1': d1,
            'Disease 2': d2,
            'Similarity': similarity,
            'Degree 1': deg1,
            'Degree 2': deg2,
            'Avg Degree': avg_deg,
            'Misdiagnosis Risk Score': misdiagnosis_score
        })

# Convert to DataFrame
risk_df = pd.DataFrame(scored_pairs)

# Sort by score in descending order
risk_df = risk_df.sort_values(by='Misdiagnosis Risk Score', ascending=False)

# Save or display top results
risk_df.to_csv('misdiagnosis_risk_scores.csv', index=False)
print(risk_df.head(10))  # Show top 10 highest-risk pairs
# Out:
#                         Disease 1  \
# 48552  infectious gastroenteritis
# 38763                   gastritis
# 18672               cholecystitis
# 2657           acute bronchospasm
# 10950                 atelectasis
# 2179             acute bronchitis
# 4254        acute stress reaction
# 47148                 hypovolemia
# 3577           acute pancreatitis
# 52406                kidney stone
#
#                                           Disease 2  Similarity  Degree 1  \
# 48552                 noninfectious gastroenteritis    0.916667       333
# 38763                                   hypokalemia    0.700000       363
# 18672                                     gallstone    0.870388       302
# 2657                                      pneumonia    0.870388       289
# 10950                          poisoning due to gas    0.771517       335
# 2179   chronic obstructive pulmonary disease (copd)    0.870388       323
# 4254                                        anxiety    0.696311       381
# 47148          persistent vomiting of unknown cause    0.755929       322
# 3577                                      gallstone    0.783349       321
# 52406                                pyelonephritis    0.909091       263
#
#        Degree 2  Avg Degree  Misdiagnosis Risk Score
# 48552       333       333.0               305.250000
# 38763       403       383.0               268.100000
# 18672       299       300.5               261.551678
# 2657        307       298.0               259.375707
# 10950       327       331.0               255.372044
# 2179        247       285.0               248.060660
# 4254        328       354.5               246.842116
# 47148       326       324.0               244.920979
# 3577        299       310.0               242.838330
# 52406       271       267.0               242.727273
